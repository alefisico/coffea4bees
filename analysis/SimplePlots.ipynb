# %%
import gzip
import os
import warnings
from pathlib import Path

import matplotlib.pyplot as plt
import mplhep as mpl
import numpy as np
# from analysis.configs import Charmonium
from coffea import hist
from coffea.util import load
from hist.axis import Regular, Variable
from matplotlib.colors import LogNorm
from matplotlib.patches import Rectangle

# %%
hists = load("hists/test.coffea")
hists
# Out:
# {'cutflow': defaultdict_accumulator(functools.partial(<class 'coffea.processor.accumulator.defaultdict_accumulator'>, functools.partial(<class 'coffea.processor.accumulator.defaultdict_accumulator'>, functools.partial(<class 'coffea.processor.accumulator.defaultdict_accumulator'>, <class 'float'>))),
#                          {'JES_Central': defaultdict_accumulator(functools.partial(<class 'coffea.processor.accumulator.defaultdict_accumulator'>, functools.partial(<class 'coffea.processor.accumulator.defaultdict_accumulator'>, <class 'float'>)),
#                                                   {'threeTag': defaultdict_accumulator(functools.partial(<class 'coffea.processor.accumulator.defaultdict_accumulator'>, <class 'float'>),
#                                                                            {'all': defaultdict_accumulator(float,
#                                                                                                     {'mixeddata': 111951.0,
#                                                                                                      'HH4b': 330300.0}),
#                                                                             'passMETFilter': defaultdict_accumulator(float,
#                                                                                                     {'mixeddata': 111951.0,
#                                                                                                      'HH4b': 9357.134643554688}),
#                                                                             'passJetMult': defaultdict_accumulator(float,
#                                                                                                     {'mixeddata': 111951.0,
#                                                                                                      'HH4b': 9131.193115234375}),
#                                                                             'passPreSel': defaultdict_accumulator(float,
#                                                                                                     {'mixeddata': 0.0,
#                                                                                                      'HH4b': 6688.840900433053}),
#                                                                             'passDiJetMass': defaultdict_accumulator(float,
#                                                                                                     {'mixeddata': 0.0,
#                                                                                                      'HH4b': 3874.391553126918}),
#                                                                             'SR': defaultdict_accumulator(float,
#                                                                                                     {'mixeddata': 0.0,
#                                                                                                      'HH4b': 2769.020227832161}),
#                                                                             'passJetMult_btagSF': defaultdict_accumulator(float,
#                                                                                                     {'HH4b': 8224.89427583513}),
#                                                                             'passPreSel_HLT_Bool': defaultdict_accumulator(float,
#                                                                                                     {'HH4b': 3766.374409656777}),
#                                                                             'passPreSel_HLT_MC': defaultdict_accumulator(float,
#                                                                                                     {'HH4b': 2650.6207802541476}),
#                                                                             'passPreSel_HLT_Data': defaultdict_accumulator(float,
#                                                                                                     {'HH4b': 2156.57371134539}),
#                                                                             'passDiJetMass_HLT_Bool': defaultdict_accumulator(float,
#                                                                                                     {'HH4b': 2003.8396332461225}),
#                                                                             'passDiJetMass_HLT_MC': defaultdict_accumulator(float,
#                                                                                                     {'HH4b': 1408.1551332389608}),
#                                                                             'passDiJetMass_HLT_Data': defaultdict_accumulator(float,
#                                                                                                     {'HH4b': 1152.6793745615014}),
#                                                                             'SR_HLT_Bool': defaultdict_accumulator(float,
#                                                                                                     {'HH4b': 1497.0022031677115}),
#                                                                             'SR_HLT_MC': defaultdict_accumulator(float,
#                                                                                                     {'HH4b': 1043.1794168508297}),
#                                                                             'SR_HLT_Data': defaultdict_accumulator(float,
#                                                                                                     {'HH4b': 862.8136549480344})}),
#                                                    'fourTag': defaultdict_accumulator(functools.partial(<class 'coffea.processor.accumulator.defaultdict_accumulator'>, <class 'float'>),
#                                                                            {'all': defaultdict_accumulator(float,
#                                                                                                     {'mixeddata': 111951.0,
#                                                                                                      'HH4b': 330300.0}),
#                                                                             'passMETFilter': defaultdict_accumulator(float,
#                                                                                                     {'mixeddata': 111951.0,
#                                                                                                      'HH4b': 9357.134643554688}),
#                                                                             'passJetMult': defaultdict_accumulator(float,
#                                                                                                     {'mixeddata': 111951.0,
#                                                                                                      'HH4b': 9131.193115234375}),
#                                                                             'passPreSel': defaultdict_accumulator(float,
#                                                                                                     {'mixeddata': 111951.0,
#                                                                                                      'HH4b': 1519.608809428678}),
#                                                                             'passDiJetMass': defaultdict_accumulator(float,
#                                                                                                     {'mixeddata': 26636.0,
#                                                                                                      'HH4b': 1382.8614856767329}),
#                                                                             'SR': defaultdict_accumulator(float,
#                                                                                                     {'mixeddata': 498.0,
#                                                                                                      'HH4b': 1203.6964566224663}),
#                                                                             'passJetMult_btagSF': defaultdict_accumulator(float,
#                                                                                                     {'HH4b': 8224.89427583513}),
#                                                                             'passPreSel_HLT_Bool': defaultdict_accumulator(float,
#                                                                                                     {'HH4b': 1156.9609359335354}),
#                                                                             'passPreSel_HLT_MC': defaultdict_accumulator(float,
#                                                                                                     {'HH4b': 1185.1511755433937}),
#                                                                             'passPreSel_HLT_Data': defaultdict_accumulator(float,
#                                                                                                     {'HH4b': 1027.4996590632663}),
#                                                                             'passDiJetMass_HLT_Bool': defaultdict_accumulator(float,
#                                                                                                     {'HH4b': 1037.938818499905}),
#                                                                             'passDiJetMass_HLT_MC': defaultdict_accumulator(float,
#                                                                                                     {'HH4b': 1062.8590978841512}),
#                                                                             'passDiJetMass_HLT_Data': defaultdict_accumulator(float,
#                                                                                                     {'HH4b': 921.7740076860945}),
#                                                                             'SR_HLT_Bool': defaultdict_accumulator(float,
#                                                                                                     {'HH4b': 915.7463107258703}),
#                                                                             'SR_HLT_MC': defaultdict_accumulator(float,
#                                                                                                     {'HH4b': 936.5717038665796}),
#                                                                             'SR_HLT_Data': defaultdict_accumulator(float,
#                                                                                                     {'HH4b': 812.9198757323865})})})}),
#  'nEvent': defaultdict_accumulator(int, {'mixeddata': 111951, 'HH4b': 94989}),
#  'hists': {'JES_Central': {'passPreSel': {'threeTag': {'SR': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47d8722e0>,
#       'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47d872c40>,
#       'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47d872130>,
#       'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47d872dc0>,
#       'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47d872520>,
#       'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47d872bb0>,
#       'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47d8726d0>,
#       'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47d872f10>,
#       'nJet_selected': <Hist (dataset,x) instance at 0x7ff47d872310>,
#       'canJet.pt': <Hist (dataset,x) instance at 0x7ff47d87d070>,
#       'canJet.eta': <Hist (dataset,x) instance at 0x7ff47d87dac0>,
#       'canJet.phi': <Hist (dataset,x) instance at 0x7ff47d87dc70>,
#       'canJet.mass': <Hist (dataset,x) instance at 0x7ff47d87d520>,
#       'canJet.pz': <Hist (dataset,x) instance at 0x7ff47d87de20>,
#       'canJet.energy': <Hist (dataset,x) instance at 0x7ff47d87d040>,
#       'canJet.calibration': <Hist (dataset,x) instance at 0x7ff47d87d5b0>,
#       'v4j.pt': <Hist (dataset,x) instance at 0x7ff47d87d5e0>,
#       'v4j.eta': <Hist (dataset,x) instance at 0x7ff47d87db50>,
#       'v4j.phi': <Hist (dataset,x) instance at 0x7ff47d7fc5e0>,
#       'v4j.mass': <Hist (dataset,x) instance at 0x7ff47d6e2dc0>,
#       'v4j.pz': <Hist (dataset,x) instance at 0x7ff47d87dd90>,
#       'v4j.energy': <Hist (dataset,x) instance at 0x7ff47d887940>,
#       'quadJet_selected.lead.pt': <Hist (dataset,x) instance at 0x7ff47d8872e0>,
#       'quadJet_selected.lead.eta': <Hist (dataset,x) instance at 0x7ff47d887c40>,
#       'quadJet_selected.lead.phi': <Hist (dataset,x) instance at 0x7ff47d8d7cd0>,
#       'quadJet_selected.lead.mass': <Hist (dataset,x) instance at 0x7ff47d8d7280>,
#       'quadJet_selected.lead.pz': <Hist (dataset,x) instance at 0x7ff47d8d7610>,
#       'quadJet_selected.lead.energy': <Hist (dataset,x) instance at 0x7ff47d8d75b0>,
#       'quadJet_selected.lead.dr': <Hist (dataset,x) instance at 0x7ff47d85dd60>,
#       'quadJet_selected.lead.st': <Hist (dataset,x) instance at 0x7ff47d85da30>,
#       'quadJet_selected.subl.pt': <Hist (dataset,x) instance at 0x7ff47d85dac0>,
#       'quadJet_selected.subl.eta': <Hist (dataset,x) instance at 0x7ff47d85d9d0>,
#       'quadJet_selected.subl.phi': <Hist (dataset,x) instance at 0x7ff47d865a00>,
#       'quadJet_selected.subl.mass': <Hist (dataset,x) instance at 0x7ff47d865400>,
#       'quadJet_selected.subl.pz': <Hist (dataset,x) instance at 0x7ff47d865760>,
#       'quadJet_selected.subl.energy': <Hist (dataset,x) instance at 0x7ff47d865a60>,
#       'quadJet_selected.subl.dr': <Hist (dataset,x) instance at 0x7ff47d86b4f0>,
#       'quadJet_selected.subl.st': <Hist (dataset,x) instance at 0x7ff47d86b730>,
#       'quadJet_selected.dr': <Hist (dataset,x) instance at 0x7ff47d86beb0>,
#       'quadJet_selected.xZZ': <Hist (dataset,x) instance at 0x7ff47d891430>,
#       'quadJet_selected.xZH': <Hist (dataset,x) instance at 0x7ff47d891a00>,
#       'quadJet_selected.xHH': <Hist (dataset,x) instance at 0x7ff47d891100>}},
#     'fourTag': {'SR': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47d90cd30>,
#       'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47d90cb20>,
#       'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47d90c910>,
#       'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47d90c340>,
#       'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47d90c670>,
#       'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47d8aed60>,
#       'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47d8ae250>,
#       'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47d8ae850>,
#       'nJet_selected': <Hist (dataset,x) instance at 0x7ff47d8ae2e0>,
#       'canJet.pt': <Hist (dataset,x) instance at 0x7ff47d8ae640>,
#       'canJet.eta': <Hist (dataset,x) instance at 0x7ff47d901670>,
#       'canJet.phi': <Hist (dataset,x) instance at 0x7ff47d9016d0>,
#       'canJet.mass': <Hist (dataset,x) instance at 0x7ff47d901100>,
#       'canJet.pz': <Hist (dataset,x) instance at 0x7ff47d901b50>,
#       'canJet.energy': <Hist (dataset,x) instance at 0x7ff47d901640>,
#       'canJet.calibration': <Hist (dataset,x) instance at 0x7ff47d900f40>,
#       'v4j.pt': <Hist (dataset,x) instance at 0x7ff47d9004f0>,
#       'v4j.eta': <Hist (dataset,x) instance at 0x7ff47d900a00>,
#       'v4j.phi': <Hist (dataset,x) instance at 0x7ff47d900490>,
#       'v4j.mass': <Hist (dataset,x) instance at 0x7ff47d900c10>,
#       'v4j.pz': <Hist (dataset,x) instance at 0x7ff47da1a850>,
#       'v4j.energy': <Hist (dataset,x) instance at 0x7ff47da1a070>,
#       'quadJet_selected.lead.pt': <Hist (dataset,x) instance at 0x7ff47da1aaf0>,
#       'quadJet_selected.lead.eta': <Hist (dataset,x) instance at 0x7ff47da1a790>,
#       'quadJet_selected.lead.phi': <Hist (dataset,x) instance at 0x7ff47da1ab80>,
#       'quadJet_selected.lead.mass': <Hist (dataset,x) instance at 0x7ff47d9a7880>,
#       'quadJet_selected.lead.pz': <Hist (dataset,x) instance at 0x7ff47d9a7fd0>,
#       'quadJet_selected.lead.energy': <Hist (dataset,x) instance at 0x7ff47d9a7b20>,
#       'quadJet_selected.lead.dr': <Hist (dataset,x) instance at 0x7ff47d9a0250>,
#       'quadJet_selected.lead.st': <Hist (dataset,x) instance at 0x7ff47d9a07f0>,
#       'quadJet_selected.subl.pt': <Hist (dataset,x) instance at 0x7ff47d9a0370>,
#       'quadJet_selected.subl.eta': <Hist (dataset,x) instance at 0x7ff47d9a0880>,
#       'quadJet_selected.subl.phi': <Hist (dataset,x) instance at 0x7ff47d9a0c10>,
#       'quadJet_selected.subl.mass': <Hist (dataset,x) instance at 0x7ff47d9f7850>,
#       'quadJet_selected.subl.pz': <Hist (dataset,x) instance at 0x7ff47d9f7430>,
#       'quadJet_selected.subl.energy': <Hist (dataset,x) instance at 0x7ff47d9f7e50>,
#       'quadJet_selected.subl.dr': <Hist (dataset,x) instance at 0x7ff47d9f70a0>,
#       'quadJet_selected.subl.st': <Hist (dataset,x) instance at 0x7ff47da512b0>,
#       'quadJet_selected.dr': <Hist (dataset,x) instance at 0x7ff47da512e0>,
#       'quadJet_selected.xZZ': <Hist (dataset,x) instance at 0x7ff47da519a0>,
#       'quadJet_selected.xZH': <Hist (dataset,x) instance at 0x7ff47da51910>,
#       'quadJet_selected.xHH': <Hist (dataset,x) instance at 0x7ff47da51c10>,
#       'trigWeight_Bool': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47da10d90>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47da104c0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47da10bb0>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47da10850>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47da10130>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47da102e0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47da06490>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47da064f0>},
#       'trigWeight_Data': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47da06190>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47da06f40>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47da06400>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47da065b0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47d9ffa00>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47d9ffca0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47d9ff3a0>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47d9ff1c0>},
#       'trigWeight_MC': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47d9ff5e0>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47d9ffb80>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47d9ffdc0>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47d9b8280>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47d9b8040>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47d9b8340>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47d9b8a00>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47da624c0>},
#       'btagSF_central': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47da62550>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47da625e0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47da627c0>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47da62e20>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47da62cd0>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47da62a30>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47da62130>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47db0ed30>},
#       'btagSF_down_hfstats1': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47db0e1c0>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47db0e0d0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47db0e9d0>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47db0ecd0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47db0eb50>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47db0e460>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47db0e6a0>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47da3f970>},
#       'btagSF_up_hfstats1': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47da3f8b0>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47da3f1c0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47da3f3a0>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47da3f760>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47da3f850>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47da3fcd0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47da3fd00>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47db6f040>},
#       'btagSF_down_hfstats2': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47daf9f70>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47daf9700>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47daf9730>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47daf9b80>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47daf99a0>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47daf9370>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47daf9130>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47deb4fd0>},
#       'btagSF_up_hfstats2': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff5641c7430>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47db42eb0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47db42a60>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47db426a0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47db42550>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47dde7b50>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47de83310>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47de830d0>},
#       'btagSF_down_lfstats1': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47d5337f0>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47d533970>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47d533b50>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47d533d30>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47d533f10>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47da34130>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47da34310>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47da344f0>},
#       'btagSF_up_lfstats1': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47da346d0>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47da348b0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47da34a90>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47da34c70>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47da34e50>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47da39070>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47da39250>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47da39430>},
#       'btagSF_down_lfstats2': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47da39610>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47da397f0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47da399d0>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47da39bb0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47da39d90>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47da39f70>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47da40190>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47da40370>},
#       'btagSF_up_lfstats2': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47da40550>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47da40730>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47da40910>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47da40af0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47da40cd0>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47da40eb0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47d8a70d0>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47d8a72b0>},
#       'btagSF_down_hf': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47d8a7490>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47d8a7670>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47d8a7850>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47d8a7a30>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47d8a7c10>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47d8a7df0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47d8a7fd0>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47d8ba1c0>},
#       'btagSF_up_hf': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47d8ba3a0>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47d8ba580>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47d8ba760>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47d8ba940>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47d8bab20>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47d8bacd0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47d8bad30>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47d8b2130>},
#       'btagSF_down_lf': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47d8b2310>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47d8b24f0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47d8b26d0>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47d8b28b0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47d8b2a90>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47d8b2c70>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47d8b2e50>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47d8b7070>},
#       'btagSF_up_lf': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47d8b7250>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47d8b7430>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47d8b7610>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47d8b77f0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47d8b79d0>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47d8b7bb0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47d8b7d90>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47d8b7f70>},
#       'btagSF_down_cferr1': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47d8bf190>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47d8bf370>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47d8bf550>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47d8bf730>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47d8bf910>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47d8bfaf0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47d8bfcd0>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47d8bfeb0>},
#       'btagSF_up_cferr1': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47d8c50d0>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47d8c52b0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47d8c5490>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47d8c5670>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47d8c5850>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47d8c5a30>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47d8c5c10>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47d8c5df0>},
#       'btagSF_down_cferr2': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47d8c5fd0>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47d8cd1f0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47d8cd3d0>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47d8cd5b0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47d8cd790>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47d8cd970>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47d8cdb50>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47d8cdd30>},
#       'btagSF_up_cferr2': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47d8cdf10>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47d6e4130>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47d6e4310>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47d6e44f0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47d6e46d0>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47d6e48b0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47d6e4a90>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47d6e4c70>},
#       'JES_Central': {},
#       'puWeight_unit': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47d6e4e50>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47d6ea070>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47d6ea250>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47d6ea430>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47d6ea610>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47d6ea7f0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47d6ea9d0>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47d6eabb0>},
#       'prefire_unit': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47d6ead90>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47d6eaf70>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47d707370>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47d707550>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47d707730>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47d707910>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47d707af0>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47d707cd0>},
#       'puWeight_up': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47d707eb0>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47d7071c0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47d714100>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47d7142e0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47d7144c0>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47d7146a0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47d714880>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47d714a60>},
#       'prefire_up': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47d714c40>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47d714e20>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47d71c040>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47d71c220>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47d71c400>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47d71c5e0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47d71c7c0>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47d71c9a0>},
#       'puWeight_down': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47d71cb80>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47d71cd60>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47d71cf40>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47d69fc40>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47d69f1f0>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47d69f3d0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47d69f5b0>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47d69f790>},
#       'prefire_down': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47d69fa60>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47d69faf0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47d69ffd0>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47d6b4a30>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47d6b40a0>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47d6b4310>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47d6b4520>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47d6b46a0>},
#       'puWeight_central': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47d6b4be0>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47d6b4dc0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47d6b4fa0>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47d6b48e0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47d6a6190>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47d6a6370>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47d6a6550>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47d6a6730>},
#       'prefire_central': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff47d6a6910>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff47d6a6af0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff47d6a6cd0>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff47d6a6eb0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff47d6ae0d0>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff47d6ae2b0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff47d6ae490>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff47d6ae670>}}}}}}}

# %%
# print(hists['hists']['JES_Central']['passPreSel']['fourTag']['SR'].keys())
hists['hists']['JES_Central']['passPreSel']['fourTag']['SR']['v4j.mass'][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 # print(hists['hists']['JES_Central']['passPreSel']['fourTag']['SR'].keys())
# ----> 2 hists['hists']['JES_Central']['passPreSel']['fourTag']['SR']['v4j.mass'][0]
#
# File ~/work/miniforge3/envs/coffeaEnv/lib/python3.9/site-packages/coffea/hist/hist_tools.py:1009, in Hist.__getitem__(self, keys)
#    1007 for s, ax in zip(keys, self._axes):
#    1008     if isinstance(ax, SparseAxis):
# -> 1009         sparse_idx.append(ax._ireduce(s))
#    1010         new_dims.append(ax)
#    1011     else:
#
# File ~/work/miniforge3/envs/coffeaEnv/lib/python3.9/site-packages/coffea/hist/hist_tools.py:394, in Cat._ireduce(self, the_slice)
#     392     out = self._sorted[start:stop]
#     393 else:
# --> 394     raise IndexError(
#     395         "Cannot understand slice %r on axis %r" % (the_slice, self)
#     396     )
#     397 return [self._bins[k] for k in out]
#
# IndexError: Cannot understand slice 0 on axis <Cat (name=dataset) instance at 0x7ff47dec4d60>

# %%
ax = hist.plot1d(hists['hists']['JES_Central']['passPreSel']['fourTag']['SR']['canJet.pt'], overlay='dataset')

# %%
for i,j in hists['cutflow']['JES_Central']['fourTag'].items():
    print(i,j.values())
# Out:
# all dict_values([111951.0, 330300.0])
# passMETFilter dict_values([111951.0, 9357.134643554688])
# passJetMult dict_values([111951.0, 9131.193115234375])
# passPreSel dict_values([111951.0, 1519.608809428678])
# passDiJetMass dict_values([26636.0, 1382.8614856767329])
# SR dict_values([498.0, 1203.6964566224663])
# passJetMult_btagSF dict_values([8224.89427583513])
# passPreSel_HLT_Bool dict_values([1156.9609359335354])
# passPreSel_HLT_MC dict_values([1185.1511755433937])
# passPreSel_HLT_Data dict_values([1027.4996590632663])
# passDiJetMass_HLT_Bool dict_values([1037.938818499905])
# passDiJetMass_HLT_MC dict_values([1062.8590978841512])
# passDiJetMass_HLT_Data dict_values([921.7740076860945])
# SR_HLT_Bool dict_values([915.7463107258703])
# SR_HLT_MC dict_values([936.5717038665796])
# SR_HLT_Data dict_values([812.9198757323865])

# %%
hists['hists']['JES_Central']['passPreSel']['fourTag']['SR'].keys()# ['passDiJetMass']['v4j.mass']
# Out:
# dict_keys(['SvB_ps_zz', 'SvB_ps_zh', 'SvB_ps_hh', 'SvB_ps_all', 'SvB_MA_ps_zz', 'SvB_MA_ps_zh', 'SvB_MA_ps_hh', 'SvB_MA_ps_all', 'nJet_selected', 'canJet.pt', 'canJet.eta', 'canJet.phi', 'canJet.mass', 'canJet.pz', 'canJet.energy', 'canJet.calibration', 'v4j.pt', 'v4j.eta', 'v4j.phi', 'v4j.mass', 'v4j.pz', 'v4j.energy', 'quadJet_selected.lead.pt', 'quadJet_selected.lead.eta', 'quadJet_selected.lead.phi', 'quadJet_selected.lead.mass', 'quadJet_selected.lead.pz', 'quadJet_selected.lead.energy', 'quadJet_selected.lead.dr', 'quadJet_selected.lead.st', 'quadJet_selected.subl.pt', 'quadJet_selected.subl.eta', 'quadJet_selected.subl.phi', 'quadJet_selected.subl.mass', 'quadJet_selected.subl.pz', 'quadJet_selected.subl.energy', 'quadJet_selected.subl.dr', 'quadJet_selected.subl.st', 'quadJet_selected.dr', 'quadJet_selected.xZZ', 'quadJet_selected.xZH', 'quadJet_selected.xHH', 'trigWeight_Bool', 'trigWeight_Data', 'trigWeight_MC', 'btagSF_central', 'btagSF_down_hfstats1', 'btagSF_up_hfstats1', 'btagSF_down_hfstats2', 'btagSF_up_hfstats2', 'btagSF_down_lfstats1', 'btagSF_up_lfstats1', 'btagSF_down_lfstats2', 'btagSF_up_lfstats2', 'btagSF_down_hf', 'btagSF_up_hf', 'btagSF_down_lf', 'btagSF_up_lf', 'btagSF_down_cferr1', 'btagSF_up_cferr1', 'btagSF_down_cferr2', 'btagSF_up_cferr2', 'JES_Central', 'puWeight_unit', 'prefire_unit', 'puWeight_up', 'prefire_up', 'puWeight_down', 'prefire_down', 'puWeight_central', 'prefire_central'])

# %%
|
