# %%
import gzip
import os
import warnings
from pathlib import Path

import matplotlib.pyplot as plt
import mplhep as mpl
import numpy as np
# from analysis.configs import Charmonium
from coffea import hist
from coffea.util import load
from hist.axis import Regular, Variable
from matplotlib.colors import LogNorm
from matplotlib.patches import Rectangle

# %%
hists = load("hists/test.coffea")
hists
# Out:
# {'cutflow': defaultdict_accumulator(functools.partial(<class 'coffea.processor.accumulator.defaultdict_accumulator'>, functools.partial(<class 'coffea.processor.accumulator.defaultdict_accumulator'>, functools.partial(<class 'coffea.processor.accumulator.defaultdict_accumulator'>, <class 'float'>))),
#                          {'JES_Central': defaultdict_accumulator(functools.partial(<class 'coffea.processor.accumulator.defaultdict_accumulator'>, functools.partial(<class 'coffea.processor.accumulator.defaultdict_accumulator'>, <class 'float'>)),
#                                                   {'threeTag': defaultdict_accumulator(functools.partial(<class 'coffea.processor.accumulator.defaultdict_accumulator'>, <class 'float'>),
#                                                                            {'all': defaultdict_accumulator(float,
#                                                                                                     {'HH4b': 330300.0,
# ...

# %%
# print(hists['hists']['JES_Central']['passPreSel']['fourTag']['SR'].keys())
hists['hists']['JES_Central']['passPreSel']['fourTag']['SR']['v4j.mass'][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 # print(hists['hists']['JES_Central']['passPreSel']['fourTag']['SR'].keys())
# ----> 2 hists['hists']['JES_Central']['passPreSel']['fourTag']['SR']['v4j.mass'][0]
#
# File ~/work/miniforge3/envs/coffeaEnv/lib/python3.9/site-packages/coffea/hist/hist_tools.py:1009, in Hist.__getitem__(self, keys)
#    1007 for s, ax in zip(keys, self._axes):
#    1008     if isinstance(ax, SparseAxis):
# -> 1009         sparse_idx.append(ax._ireduce(s))
#    1010         new_dims.append(ax)
#    1011     else:
#
# File ~/work/miniforge3/envs/coffeaEnv/lib/python3.9/site-packages/coffea/hist/hist_tools.py:394, in Cat._ireduce(self, the_slice)
#     392     out = self._sorted[start:stop]
#     393 else:
# --> 394     raise IndexError(
#     395         "Cannot understand slice %r on axis %r" % (the_slice, self)
# ...

# %%
# fig, axs = plt.subplots(1, 2, figsize=(9, 4))
# # mpl.histplot(hists['hists']['JES_Central']['passPreSel']['fourTag']['SR']['v4j.mass'].project("dataset","x"), ax=axs[0])
# # hists['hists']['JES_Central']['passPreSel']['fourTag']['SR']['v4j.mass'].project("x").plot(ax=axs[0])
# a = hists['hists']['JES_Central']['passPreSel']['fourTag']['SR']['v4j.mass'].project("x")
# mpl.histplot(a, ax=axs[0])
# # h: dict[str, Hist]hists['hists']
# # type(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 5
#       2 # mpl.histplot(hists['hists']['JES_Central']['passPreSel']['fourTag']['SR']['v4j.mass'].project("dataset","x"), ax=axs[0])
#       3 # hists['hists']['JES_Central']['passPreSel']['fourTag']['SR']['v4j.mass'].project("x").plot(ax=axs[0])
#       4 a = hists['hists']['JES_Central']['passPreSel']['fourTag']['SR']['v4j.mass'].project("x")
# ----> 5 mpl.histplot(a, ax=axs[0])
#       6 # h: dict[str, Hist]hists['hists']
#       7 # type(a)
#
# File ~/work/miniforge3/envs/coffeaEnv/lib/python3.9/site-packages/mplhep/plot.py:172, in histplot(H, bins, yerr, w2, w2method, stack, density, binwnorm, histtype, xerr, label, sort, edges, binticks, ax, flow, **kwargs)
#     169 binticks = bool(binticks)
#     171 # Process input
# --> 172 hists = list(process_histogram_parts(H, bins))
# ...

# %%
ax = hist.plot1d(hists['hists']['JES_Central']['passPreSel']['fourTag']['SR']['v4j.mass'], overlay='dataset')
# Out:
# /home/alejandro/work/miniforge3/envs/coffeaEnv/lib/python3.9/site-packages/coffea/hist/plot.py:43: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(

# %%
hists['hists']['JES_Central']['passPreSel']['fourTag']['SR']['v4j.mass']
# Out:
# <Hist (dataset,x) instance at 0x7f7ae2a7ac40>

# %%
|
