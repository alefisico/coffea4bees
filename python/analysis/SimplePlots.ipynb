# %%
import gzip
import os
import warnings
from pathlib import Path

import matplotlib.pyplot as plt
import mplhep as mpl
import numpy as np
# from analysis.configs import Charmonium
from coffea import hist
from coffea.util import load
from hist.axis import Regular, Variable
from matplotlib.colors import LogNorm
from matplotlib.patches import Rectangle
# Out:
# /home/alejandro/work/miniforge3/envs/coffeaEnv/lib/python3.9/site-packages/coffea/util.py:154: FutureWarning: In coffea version v2023.3.0 (target date: 31 Mar 2023), this will be an error.
# (Set coffea.deprecations_as_errors = True to get a stack trace now.)
# ImportError: coffea.hist is deprecated
#   warnings.warn(message, FutureWarning)

# %%
hists = load("hists/test.coffea")
hists
# Out:
# {'cutflow': defaultdict_accumulator(functools.partial(<class 'coffea.processor.accumulator.defaultdict_accumulator'>, functools.partial(<class 'coffea.processor.accumulator.defaultdict_accumulator'>, functools.partial(<class 'coffea.processor.accumulator.defaultdict_accumulator'>, <class 'float'>))),
#                          {'JES_Central': defaultdict_accumulator(functools.partial(<class 'coffea.processor.accumulator.defaultdict_accumulator'>, functools.partial(<class 'coffea.processor.accumulator.defaultdict_accumulator'>, <class 'float'>)),
#                                                   {'threeTag': defaultdict_accumulator(functools.partial(<class 'coffea.processor.accumulator.defaultdict_accumulator'>, <class 'float'>),
#                                                                            {'all': defaultdict_accumulator(float,
#                                                                                                     {'dataUL18D': 882.7734909057617,
#                                                                                                      'dataUL18C': 902.0614318847656,
#                                                                                                      'dataUL18B': 930.413703918457,
#                                                                                                      'dataUL18A': 939.9942016601562,
#                                                                                                      'mixeddata': 10000.0,
#                                                                                                      'HH4b': 598000.0}),
#                                                                             'passMETFilter': defaultdict_accumulator(float,
#                                                                                                     {'dataUL18D': 880.5957412719727,
#                                                                                                      'dataUL18C': 901.9337387084961,
#                                                                                                      'dataUL18B': 928.7193603515625,
#                                                                                                      'dataUL18A': 939.6951675415039,
#                                                                                                      'mixeddata': 10000.0,
#                                                                                                      'HH4b': 1491.7332153320312}),
#                                                                             'passJetMult': defaultdict_accumulator(float,
#                                                                                                     {'dataUL18D': 880.5957412719727,
#                                                                                                      'dataUL18C': 901.9337387084961,
#                                                                                                      'dataUL18B': 928.7193603515625,
#                                                                                                      'dataUL18A': 939.6951675415039,
#                                                                                                      'mixeddata': 10000.0,
#                                                                                                      'HH4b': 1454.50048828125}),
#                                                                             'passPreSel': defaultdict_accumulator(float,
#                                                                                                     {'dataUL18D': 520.5957336425781,
#                                                                                                      'dataUL18C': 526.9337730407715,
#                                                                                                      'dataUL18B': 525.7193946838379,
#                                                                                                      'dataUL18A': 524.6951751708984,
#                                                                                                      'mixeddata': 0.0,
#                                                                                                      'HH4b': 1111.280142755509}),
#                                                                             'passDiJetMass': defaultdict_accumulator(float,
#                                                                                                     {'dataUL18D': 169.67676162719727,
#                                                                                                      'dataUL18C': 172.18145370483398,
#                                                                                                      'dataUL18B': 173.9894199371338,
#                                                                                                      'dataUL18A': 173.46365928649902,
#                                                                                                      'mixeddata': 0.0,
#                                                                                                      'HH4b': 648.3331755625748}),
#                                                                             'SR': defaultdict_accumulator(float,
#                                                                                                     {'dataUL18D': 66.21575975418091,
#                                                                                                      'dataUL18C': 66.19786787033081,
#                                                                                                      'dataUL18B': 70.781081199646,
#                                                                                                      'dataUL18A': 68.32001113891602,
#                                                                                                      'mixeddata': 0.0,
#                                                                                                      'HH4b': 463.22507372711175}),
#                                                                             'passJetMult_btagSF': defaultdict_accumulator(float,
#                                                                                                     {'HH4b': 1351.3702739105972})}),
#                                                    'fourTag': defaultdict_accumulator(functools.partial(<class 'coffea.processor.accumulator.defaultdict_accumulator'>, <class 'float'>),
#                                                                            {'all': defaultdict_accumulator(float,
#                                                                                                     {'dataUL18D': 882.7734909057617,
#                                                                                                      'dataUL18C': 902.0614318847656,
#                                                                                                      'dataUL18B': 930.413703918457,
#                                                                                                      'dataUL18A': 939.9942016601562,
#                                                                                                      'mixeddata': 10000.0,
#                                                                                                      'HH4b': 598000.0}),
#                                                                             'passMETFilter': defaultdict_accumulator(float,
#                                                                                                     {'dataUL18D': 880.5957412719727,
#                                                                                                      'dataUL18C': 901.9337387084961,
#                                                                                                      'dataUL18B': 928.7193603515625,
#                                                                                                      'dataUL18A': 939.6951675415039,
#                                                                                                      'mixeddata': 10000.0,
#                                                                                                      'HH4b': 1491.7332153320312}),
#                                                                             'passJetMult': defaultdict_accumulator(float,
#                                                                                                     {'dataUL18D': 880.5957412719727,
#                                                                                                      'dataUL18C': 901.9337387084961,
#                                                                                                      'dataUL18B': 928.7193603515625,
#                                                                                                      'dataUL18A': 939.6951675415039,
#                                                                                                      'mixeddata': 10000.0,
#                                                                                                      'HH4b': 1454.50048828125}),
#                                                                             'passPreSel': defaultdict_accumulator(float,
#                                                                                                     {'dataUL18D': 360.0,
#                                                                                                      'dataUL18C': 375.0,
#                                                                                                      'dataUL18B': 403.0,
#                                                                                                      'dataUL18A': 415.0,
#                                                                                                      'mixeddata': 10000.0,
#                                                                                                      'HH4b': 237.5011408699877}),
#                                                                             'passDiJetMass': defaultdict_accumulator(float,
#                                                                                                     {'dataUL18D': 89.0,
#                                                                                                      'dataUL18C': 99.0,
#                                                                                                      'dataUL18B': 93.0,
#                                                                                                      'dataUL18A': 111.0,
#                                                                                                      'mixeddata': 3491.0,
#                                                                                                      'HH4b': 212.30473732013476}),
#                                                                             'SR': defaultdict_accumulator(float,
#                                                                                                     {'dataUL18D': 3.0,
#                                                                                                      'dataUL18C': 4.0,
#                                                                                                      'dataUL18B': 2.0,
#                                                                                                      'dataUL18A': 4.0,
#                                                                                                      'mixeddata': 1304.0,
#                                                                                                      'HH4b': 184.93674744112352}),
#                                                                             'passJetMult_btagSF': defaultdict_accumulator(float,
#                                                                                                     {'HH4b': 1351.3702739105972})})})}),
#  'nEvent': defaultdict_accumulator(int,
#                          {'dataUL18D': 10000,
#                           'dataUL18C': 10020,
#                           'dataUL18B': 10000,
#                           'dataUL18A': 10010,
#                           'mixeddata': 10000,
#                           'HH4b': 9990}),
#  'hists': {'JES_Central': {'passPreSel': {'threeTag': {'SR': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f097f940>,
#       'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f09151f0>,
#       'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f0915a00>,
#       'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f091d250>,
#       'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f091da60>,
#       'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f09242b0>,
#       'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f0924ac0>,
#       'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f092c310>,
#       'nJet_selected': <Hist (dataset,x) instance at 0x7ff0f092cb20>,
#       'canJet.pt': <Hist (dataset,x) instance at 0x7ff0f0934370>,
#       'canJet.eta': <Hist (dataset,x) instance at 0x7ff0f0934b80>,
#       'canJet.phi': <Hist (dataset,x) instance at 0x7ff0f093d3d0>,
#       'canJet.mass': <Hist (dataset,x) instance at 0x7ff0f093dbe0>,
#       'canJet.pz': <Hist (dataset,x) instance at 0x7ff0f0947430>,
#       'canJet.energy': <Hist (dataset,x) instance at 0x7ff0f0947c40>,
#       'canJet.calibration': <Hist (dataset,x) instance at 0x7ff0f08ce490>,
#       'v4j.pt': <Hist (dataset,x) instance at 0x7ff0f08ce5e0>,
#       'v4j.eta': <Hist (dataset,x) instance at 0x7ff0f08cee20>,
#       'v4j.phi': <Hist (dataset,x) instance at 0x7ff0f08d9670>,
#       'v4j.mass': <Hist (dataset,x) instance at 0x7ff0f08d9e80>,
#       'v4j.pz': <Hist (dataset,x) instance at 0x7ff0f08e06d0>,
#       'v4j.energy': <Hist (dataset,x) instance at 0x7ff0f08e0ee0>,
#       'quadJet_selected.lead.pt': <Hist (dataset,x) instance at 0x7ff0f08e7730>,
#       'quadJet_selected.lead.eta': <Hist (dataset,x) instance at 0x7ff0f08e7f40>,
#       'quadJet_selected.lead.phi': <Hist (dataset,x) instance at 0x7ff0f08f0790>,
#       'quadJet_selected.lead.mass': <Hist (dataset,x) instance at 0x7ff0f08f0fa0>,
#       'quadJet_selected.lead.pz': <Hist (dataset,x) instance at 0x7ff0f08f97f0>,
#       'quadJet_selected.lead.energy': <Hist (dataset,x) instance at 0x7ff0f0901040>,
#       'quadJet_selected.lead.dr': <Hist (dataset,x) instance at 0x7ff0f0901850>,
#       'quadJet_selected.lead.st': <Hist (dataset,x) instance at 0x7ff0f088a0a0>,
#       'quadJet_selected.subl.pt': <Hist (dataset,x) instance at 0x7ff0f088a8b0>,
#       'quadJet_selected.subl.eta': <Hist (dataset,x) instance at 0x7ff0f0891100>,
#       'quadJet_selected.subl.phi': <Hist (dataset,x) instance at 0x7ff0f0891910>,
#       'quadJet_selected.subl.mass': <Hist (dataset,x) instance at 0x7ff0f089a160>,
#       'quadJet_selected.subl.pz': <Hist (dataset,x) instance at 0x7ff0f089a970>,
#       'quadJet_selected.subl.energy': <Hist (dataset,x) instance at 0x7ff0f08a31c0>,
#       'quadJet_selected.subl.dr': <Hist (dataset,x) instance at 0x7ff0f08a39d0>,
#       'quadJet_selected.subl.st': <Hist (dataset,x) instance at 0x7ff0f08ac220>,
#       'quadJet_selected.dr': <Hist (dataset,x) instance at 0x7ff0f08aca30>,
#       'quadJet_selected.xZZ': <Hist (dataset,x) instance at 0x7ff0f08b3280>,
#       'quadJet_selected.xZH': <Hist (dataset,x) instance at 0x7ff0f08b3a90>,
#       'quadJet_selected.xHH': <Hist (dataset,x) instance at 0x7ff0f08bc2e0>},
#      'inclusive': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f08bcaf0>,
#       'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f08c3280>,
#       'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f08c39d0>,
#       'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f084b160>,
#       'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f084b8b0>,
#       'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f0853040>,
#       'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f0853790>,
#       'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f0853ee0>,
#       'nJet_selected': <Hist (dataset,x) instance at 0x7ff0f085b670>,
#       'canJet.pt': <Hist (dataset,x) instance at 0x7ff0f085bdc0>,
#       'canJet.eta': <Hist (dataset,x) instance at 0x7ff0f0860550>,
#       'canJet.phi': <Hist (dataset,x) instance at 0x7ff0f0860ca0>,
#       'canJet.mass': <Hist (dataset,x) instance at 0x7ff0f0868430>,
#       'canJet.pz': <Hist (dataset,x) instance at 0x7ff0f0868b80>,
#       'canJet.energy': <Hist (dataset,x) instance at 0x7ff0f0873310>,
#       'canJet.calibration': <Hist (dataset,x) instance at 0x7ff0f0873a60>,
#       'v4j.pt': <Hist (dataset,x) instance at 0x7ff0f0873af0>,
#       'v4j.eta': <Hist (dataset,x) instance at 0x7ff0f087a2b0>,
#       'v4j.phi': <Hist (dataset,x) instance at 0x7ff0f087aa00>,
#       'v4j.mass': <Hist (dataset,x) instance at 0x7ff0f0884190>,
#       'v4j.pz': <Hist (dataset,x) instance at 0x7ff0f08848e0>,
#       'v4j.energy': <Hist (dataset,x) instance at 0x7ff0f080c070>,
#       'quadJet_selected.lead.pt': <Hist (dataset,x) instance at 0x7ff0f080c7c0>,
#       'quadJet_selected.lead.eta': <Hist (dataset,x) instance at 0x7ff0f080cf10>,
#       'quadJet_selected.lead.phi': <Hist (dataset,x) instance at 0x7ff0f08156a0>,
#       'quadJet_selected.lead.mass': <Hist (dataset,x) instance at 0x7ff0f0815df0>,
#       'quadJet_selected.lead.pz': <Hist (dataset,x) instance at 0x7ff0f081c580>,
#       'quadJet_selected.lead.energy': <Hist (dataset,x) instance at 0x7ff0f081ccd0>,
#       'quadJet_selected.lead.dr': <Hist (dataset,x) instance at 0x7ff0f0824460>,
#       'quadJet_selected.lead.st': <Hist (dataset,x) instance at 0x7ff0f0824bb0>,
#       'quadJet_selected.subl.pt': <Hist (dataset,x) instance at 0x7ff0f082d340>,
#       'quadJet_selected.subl.eta': <Hist (dataset,x) instance at 0x7ff0f082da90>,
#       'quadJet_selected.subl.phi': <Hist (dataset,x) instance at 0x7ff0f0836220>,
#       'quadJet_selected.subl.mass': <Hist (dataset,x) instance at 0x7ff0f0836970>,
#       'quadJet_selected.subl.pz': <Hist (dataset,x) instance at 0x7ff0f083f100>,
#       'quadJet_selected.subl.energy': <Hist (dataset,x) instance at 0x7ff0f083f850>,
#       'quadJet_selected.subl.dr': <Hist (dataset,x) instance at 0x7ff0f083ffa0>,
#       'quadJet_selected.subl.st': <Hist (dataset,x) instance at 0x7ff0f0847730>,
#       'quadJet_selected.dr': <Hist (dataset,x) instance at 0x7ff0f0847e80>,
#       'quadJet_selected.xZZ': <Hist (dataset,x) instance at 0x7ff0f07ce610>,
#       'quadJet_selected.xZH': <Hist (dataset,x) instance at 0x7ff0f07ced60>,
#       'quadJet_selected.xHH': <Hist (dataset,x) instance at 0x7ff0f07d74f0>}},
#     'fourTag': {'SR': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f07d7c40>,
#       'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f07de3d0>,
#       'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f07deb20>,
#       'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f07e72b0>,
#       'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f07e7a00>,
#       'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f07ee190>,
#       'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f07ee8e0>,
#       'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f07f4070>,
#       'nJet_selected': <Hist (dataset,x) instance at 0x7ff0f07f47c0>,
#       'canJet.pt': <Hist (dataset,x) instance at 0x7ff0f07f4f10>,
#       'canJet.eta': <Hist (dataset,x) instance at 0x7ff0f07fb6a0>,
#       'canJet.phi': <Hist (dataset,x) instance at 0x7ff0f07fbdf0>,
#       'canJet.mass': <Hist (dataset,x) instance at 0x7ff0f0805580>,
#       'canJet.pz': <Hist (dataset,x) instance at 0x7ff0f0805cd0>,
#       'canJet.energy': <Hist (dataset,x) instance at 0x7ff0f078e460>,
#       'canJet.calibration': <Hist (dataset,x) instance at 0x7ff0f078ebb0>,
#       'v4j.pt': <Hist (dataset,x) instance at 0x7ff0f078ec40>,
#       'v4j.eta': <Hist (dataset,x) instance at 0x7ff0f0796400>,
#       'v4j.phi': <Hist (dataset,x) instance at 0x7ff0f0796b50>,
#       'v4j.mass': <Hist (dataset,x) instance at 0x7ff0f079e2e0>,
#       'v4j.pz': <Hist (dataset,x) instance at 0x7ff0f079ea30>,
#       'v4j.energy': <Hist (dataset,x) instance at 0x7ff0f07a71c0>,
#       'quadJet_selected.lead.pt': <Hist (dataset,x) instance at 0x7ff0f07a7910>,
#       'quadJet_selected.lead.eta': <Hist (dataset,x) instance at 0x7ff0f07ae0a0>,
#       'quadJet_selected.lead.phi': <Hist (dataset,x) instance at 0x7ff0f07ae7f0>,
#       'quadJet_selected.lead.mass': <Hist (dataset,x) instance at 0x7ff0f07aef40>,
#       'quadJet_selected.lead.pz': <Hist (dataset,x) instance at 0x7ff0f07b76d0>,
#       'quadJet_selected.lead.energy': <Hist (dataset,x) instance at 0x7ff0f07b7e20>,
#       'quadJet_selected.lead.dr': <Hist (dataset,x) instance at 0x7ff0f07bf5b0>,
#       'quadJet_selected.lead.st': <Hist (dataset,x) instance at 0x7ff0f07bfd00>,
#       'quadJet_selected.subl.pt': <Hist (dataset,x) instance at 0x7ff0f07c9490>,
#       'quadJet_selected.subl.eta': <Hist (dataset,x) instance at 0x7ff0f07c9be0>,
#       'quadJet_selected.subl.phi': <Hist (dataset,x) instance at 0x7ff0f074f370>,
#       'quadJet_selected.subl.mass': <Hist (dataset,x) instance at 0x7ff0f074fac0>,
#       'quadJet_selected.subl.pz': <Hist (dataset,x) instance at 0x7ff0f0757250>,
#       'quadJet_selected.subl.energy': <Hist (dataset,x) instance at 0x7ff0f07579a0>,
#       'quadJet_selected.subl.dr': <Hist (dataset,x) instance at 0x7ff0f075f130>,
#       'quadJet_selected.subl.st': <Hist (dataset,x) instance at 0x7ff0f075f880>,
#       'quadJet_selected.dr': <Hist (dataset,x) instance at 0x7ff0f075ffd0>,
#       'quadJet_selected.xZZ': <Hist (dataset,x) instance at 0x7ff0f0767760>,
#       'quadJet_selected.xZH': <Hist (dataset,x) instance at 0x7ff0f0767eb0>,
#       'quadJet_selected.xHH': <Hist (dataset,x) instance at 0x7ff0f0772640>,
#       'trigWeight_Bool': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f0772d90>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f0772f70>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f077a190>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f077a370>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f077a550>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f077a730>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f077a910>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f077aaf0>},
#       'trigWeight_Data': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f077acd0>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f077aeb0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f07810d0>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f07812b0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f0781490>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f0781670>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f0781850>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f0781a30>},
#       'trigWeight_MC': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f0781c10>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f0781df0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f0781fd0>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f070a1f0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f070a3d0>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f070a5b0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f070a790>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f070a970>},
#       'btagSF_central': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f070ab50>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f070ad30>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f070af10>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f0712130>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f0712310>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f07124f0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f07126d0>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f07128b0>},
#       'btagSF_down_hfstats1': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f0712a90>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f0712c70>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f0712e50>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f071c070>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f071c250>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f071c430>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f071c610>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f071c7f0>},
#       'btagSF_up_hfstats1': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f071c9d0>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f071cbb0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f071cd90>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f071cf70>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f0726190>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f0726370>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f0726550>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f0726730>},
#       'btagSF_down_hfstats2': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f0726910>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f0726af0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f0726cd0>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f0726eb0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f072c0d0>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f072c2b0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f072c490>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f072c670>},
#       'btagSF_up_hfstats2': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f072c850>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f072ca30>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f072cc10>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f072cdf0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f072cfd0>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f07371f0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f07373d0>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f07375b0>},
#       'btagSF_down_lfstats1': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f0737790>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f0737970>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f0737b50>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f0737d30>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f0737f10>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f073d130>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f073d310>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f073d4f0>},
#       'btagSF_up_lfstats1': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f073d6d0>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f073d8b0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f073da90>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f073dc70>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f073de50>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f0746070>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f0746250>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f0746430>},
#       'btagSF_down_lfstats2': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f0746610>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f07467f0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f07469d0>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f0746bb0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f0746d90>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f0746f70>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06cf190>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f06cf370>},
#       'btagSF_up_lfstats2': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06cf550>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06cf730>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06cf910>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f06cfaf0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06cfcd0>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06cfeb0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06d70d0>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f06d72b0>},
#       'btagSF_down_hf': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06d7490>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06d7670>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06d7850>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f06d7a30>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06d7c10>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06d7df0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06d7fd0>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f06e11f0>},
#       'btagSF_up_hf': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06e13d0>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06e15b0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06e1790>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f06e1970>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06e1b50>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06e1d30>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06e1f10>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f06e9130>},
#       'btagSF_down_lf': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06e9310>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06e94f0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06e96d0>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f06e98b0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06e9a90>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06e9c70>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06e9e50>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f06f0070>},
#       'btagSF_up_lf': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06f0250>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06f0430>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06f0610>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f06f07f0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06f09d0>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06f0bb0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06f0d90>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f06f0f70>},
#       'btagSF_down_cferr1': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06fb190>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06fb370>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06fb550>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f06fb730>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06fb910>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06fbaf0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06fbcd0>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f06fbeb0>},
#       'btagSF_up_cferr1': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f07020d0>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f07022b0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f0702490>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f0702670>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f0702850>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f0702a30>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f0702c10>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f0702df0>},
#       'btagSF_down_cferr2': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f0702fd0>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f068b1f0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f068b3d0>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f068b5b0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f068b790>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f068b970>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f068bb50>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f068bd30>},
#       'btagSF_up_cferr2': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f068bf10>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f0695130>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f0695310>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f06954f0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06956d0>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06958b0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f0695a90>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f0695c70>},
#       'JES_Central': {},
#       'puWeight_unit': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f0695e50>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f069c070>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f069c250>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f069c430>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f069c610>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f069c7f0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f069c9d0>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f069cbb0>},
#       'prefire_unit': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f069cd90>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f069ce20>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f069cee0>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f069cfa0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06a50a0>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06a5160>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06a5220>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f06a52e0>},
#       'puWeight_up': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06a53a0>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06a55b0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06a5790>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f06a5970>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06a5b50>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06a5d30>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06a5f10>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f06ae130>},
#       'prefire_up': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06ae310>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06ae3a0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06ae460>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f06ae520>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06ae5e0>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06ae6a0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06ae760>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f06ae820>},
#       'puWeight_down': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06ae8e0>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06aeaf0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06aecd0>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f06aeeb0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06b50d0>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06b52b0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06b5490>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f06b5670>},
#       'prefire_down': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06b5850>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06b58e0>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06b59a0>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f06b5a60>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06b5b20>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06b5be0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06b5ca0>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f06b5d60>},
#       'puWeight_central': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06b5e20>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06be070>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06be250>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f06be430>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06be610>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06be7f0>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06be9d0>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f06bebb0>},
#       'prefire_central': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06bed90>,
#        'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06bee20>,
#        'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06beee0>,
#        'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f06befa0>,
#        'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06c70a0>,
#        'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06c7160>,
#        'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f06c7220>,
#        'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f06c72e0>}},
#      'inclusive': {'SvB_ps_zz': <Hist (dataset,x) instance at 0x7ff0f06c73a0>,
#       'SvB_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06c7b20>,
#       'SvB_ps_hh': <Hist (dataset,x) instance at 0x7ff0f064e2b0>,
#       'SvB_ps_all': <Hist (dataset,x) instance at 0x7ff0f064ea00>,
#       'SvB_MA_ps_zz': <Hist (dataset,x) instance at 0x7ff0f0655190>,
#       'SvB_MA_ps_zh': <Hist (dataset,x) instance at 0x7ff0f06558e0>,
#       'SvB_MA_ps_hh': <Hist (dataset,x) instance at 0x7ff0f065d070>,
#       'SvB_MA_ps_all': <Hist (dataset,x) instance at 0x7ff0f065d7c0>,
#       'nJet_selected': <Hist (dataset,x) instance at 0x7ff0f065df10>,
#       'canJet.pt': <Hist (dataset,x) instance at 0x7ff0f06646a0>,
#       'canJet.eta': <Hist (dataset,x) instance at 0x7ff0f0664df0>,
#       'canJet.phi': <Hist (dataset,x) instance at 0x7ff0f066c580>,
#       'canJet.mass': <Hist (dataset,x) instance at 0x7ff0f066ccd0>,
#       'canJet.pz': <Hist (dataset,x) instance at 0x7ff0f0676460>,
#       'canJet.energy': <Hist (dataset,x) instance at 0x7ff0f0676bb0>,
#       'canJet.calibration': <Hist (dataset,x) instance at 0x7ff0f067e340>,
#       'v4j.pt': <Hist (dataset,x) instance at 0x7ff0f067e3d0>,
#       'v4j.eta': <Hist (dataset,x) instance at 0x7ff0f067eb50>,
#       'v4j.phi': <Hist (dataset,x) instance at 0x7ff0f06862e0>,
#       'v4j.mass': <Hist (dataset,x) instance at 0x7ff0f0686a30>,
#       'v4j.pz': <Hist (dataset,x) instance at 0x7ff0f06101c0>,
#       'v4j.energy': <Hist (dataset,x) instance at 0x7ff0f0610910>,
#       'quadJet_selected.lead.pt': <Hist (dataset,x) instance at 0x7ff0f06170a0>,
#       'quadJet_selected.lead.eta': <Hist (dataset,x) instance at 0x7ff0f06177f0>,
#       'quadJet_selected.lead.phi': <Hist (dataset,x) instance at 0x7ff0f0617f40>,
#       'quadJet_selected.lead.mass': <Hist (dataset,x) instance at 0x7ff0f061f6d0>,
#       'quadJet_selected.lead.pz': <Hist (dataset,x) instance at 0x7ff0f061fe20>,
#       'quadJet_selected.lead.energy': <Hist (dataset,x) instance at 0x7ff0f06295b0>,
#       'quadJet_selected.lead.dr': <Hist (dataset,x) instance at 0x7ff0f0629d00>,
#       'quadJet_selected.lead.st': <Hist (dataset,x) instance at 0x7ff0f0630490>,
#       'quadJet_selected.subl.pt': <Hist (dataset,x) instance at 0x7ff0f0630be0>,
#       'quadJet_selected.subl.eta': <Hist (dataset,x) instance at 0x7ff0f06383a0>,
#       'quadJet_selected.subl.phi': <Hist (dataset,x) instance at 0x7ff0f0638af0>,
#       'quadJet_selected.subl.mass': <Hist (dataset,x) instance at 0x7ff0f063f280>,
#       'quadJet_selected.subl.pz': <Hist (dataset,x) instance at 0x7ff0f063f9d0>,
#       'quadJet_selected.subl.energy': <Hist (dataset,x) instance at 0x7ff0f0649160>,
#       'quadJet_selected.subl.dr': <Hist (dataset,x) instance at 0x7ff0f06498b0>,
#       'quadJet_selected.subl.st': <Hist (dataset,x) instance at 0x7ff0f0649fd0>,
#       'quadJet_selected.dr': <Hist (dataset,x) instance at 0x7ff0f05d2760>,
#       'quadJet_selected.xZZ': <Hist (dataset,x) instance at 0x7ff0f05d2eb0>,
#       'quadJet_selected.xZH': <Hist (dataset,x) instance at 0x7ff0f05d9640>,
#       'quadJet_selected.xHH': <Hist (dataset,x) instance at 0x7ff0f05d9d90>}}}}}}

# %%
# ax = hist.plot1d(hists['hists']['JES_Central']['passPreSel']['fourTag']['SR']['v4j.mass'], overlay='dataset')
ax = hist.plot1d(hists['hists']['JES_Central']['passPreSel']['fourTag']['SR']['SvB_MA_ps_hh'],  overlay='dataset')
# Out:
# /home/alejandro/work/miniforge3/envs/coffeaEnv/lib/python3.9/site-packages/coffea/hist/plot.py:43: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(

# %%
for i,j in hists['cutflow']['JES_Central']['fourTag'].items():
    print(i,j.values())
# Out:
# all dict_values([111951.0, 36700.0])
# passMETFilter dict_values([111951.0, 9357.134765625])
# passJetMult dict_values([111951.0, 9131.193359375])
# passPreSel dict_values([111951.0, 1519.608809428678])
# passDiJetMass dict_values([26636.0, 1382.861485676733])
# SR dict_values([500.0, 1203.4103261553587])
# passJetMult_btagSF dict_values([8224.89427583513])
# passPreSel_HLT_Bool dict_values([1156.9609359335354])
# passPreSel_HLT_MC dict_values([1185.151175543394])
# passPreSel_HLT_Data dict_values([1027.4996590632663])
# passDiJetMass_HLT_Bool dict_values([1037.9388184999048])
# passDiJetMass_HLT_MC dict_values([1062.8590978841512])
# passDiJetMass_HLT_Data dict_values([921.7740076860944])
# SR_HLT_Bool dict_values([915.5996869759299])
# SR_HLT_MC dict_values([934.9464502995038])
# SR_HLT_Data dict_values([811.5949957806356])

# %%
hists['hists']['JES_Central']['passPreSel']['fourTag']['SR'].keys()
# Out:
# dict_keys(['SvB_ps_zz', 'SvB_ps_zh', 'SvB_ps_hh', 'SvB_ps_all', 'SvB_MA_ps_zz', 'SvB_MA_ps_zh', 'SvB_MA_ps_hh', 'SvB_MA_ps_all', 'nJet_selected', 'canJet.pt', 'canJet.eta', 'canJet.phi', 'canJet.mass', 'canJet.pz', 'canJet.energy', 'canJet.calibration', 'v4j.pt', 'v4j.eta', 'v4j.phi', 'v4j.mass', 'v4j.pz', 'v4j.energy', 'quadJet_selected.lead.pt', 'quadJet_selected.lead.eta', 'quadJet_selected.lead.phi', 'quadJet_selected.lead.mass', 'quadJet_selected.lead.pz', 'quadJet_selected.lead.energy', 'quadJet_selected.lead.dr', 'quadJet_selected.lead.st', 'quadJet_selected.subl.pt', 'quadJet_selected.subl.eta', 'quadJet_selected.subl.phi', 'quadJet_selected.subl.mass', 'quadJet_selected.subl.pz', 'quadJet_selected.subl.energy', 'quadJet_selected.subl.dr', 'quadJet_selected.subl.st', 'quadJet_selected.dr', 'quadJet_selected.xZZ', 'quadJet_selected.xZH', 'quadJet_selected.xHH', 'trigWeight_Bool', 'trigWeight_Data', 'trigWeight_MC', 'btagSF_central', 'btagSF_down_hfstats1', 'btagSF_up_hfstats1', 'btagSF_down_hfstats2', 'btagSF_up_hfstats2', 'btagSF_down_lfstats1', 'btagSF_up_lfstats1', 'btagSF_down_lfstats2', 'btagSF_up_lfstats2', 'btagSF_down_hf', 'btagSF_up_hf', 'btagSF_down_lf', 'btagSF_up_lf', 'btagSF_down_cferr1', 'btagSF_up_cferr1', 'btagSF_down_cferr2', 'btagSF_up_cferr2', 'JES_Central', 'puWeight_unit', 'prefire_unit', 'puWeight_up', 'prefire_up', 'puWeight_down', 'prefire_down', 'puWeight_central', 'prefire_central'])

# %%
|
